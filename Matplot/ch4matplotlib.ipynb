# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
y = np.random.randint(0, 10, 10)
plt.plot(y, '+b-')

# %%
power = 1
for i in range(1, 3):
  for j in range(1, 3):
    a = [x ** power for x in range(-5, 6) ]
    y = np.array(a)
    x = np.array([x for x in range(-5, 6)])
    plt.subplot(2, 2, power)
    plt.plot(x, y)
    power += 1

# %% [markdown]
# Scatter plot

# %%
x = 4 + np.random.normal(0, 2, 50)
y = 4 + np.random.normal(0, 2, len(x))
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))
plt.scatter(x, y, c = colors, s = sizes)

# %% [markdown]
# Example - plotting various charts on a dataset

# %%
df = pd.read_csv('/USACities.csv')
df.head()
# Out:
#    rank           name usps  pop2021  pop2010  growth  density  aland_sqmi
# 0     1  New York City   NY  8230290  8190210  0.0049    27400     300.381
# 1     2    Los Angeles   CA  3983540  3795510  0.0495     8494     468.956
# 2     3        Chicago   IL  2679080  2697480 -0.0068    11783     227.369
# 3     4        Houston   TX  2323660  2100280  0.1064     3630     640.194
# 4     5        Phoenix   AZ  1733630  1449040  0.1964     3349     517.673

# %%
x = [i for i in range(0, 10)]
cities = df['name'][0:10]
y = df['pop2021'][0:10]
sizes = df['pop2010'][0:10]
sizes /= 10000
plt.xticks(x, cities)
plt.scatter(x, y, s = sizes)

# %%
x = df['density'][0:5]
labels = df['name'][0:5]
colors = plt.get_cmap('Greens')(np.linspace(0.2, 0.7, len(x)))
plt.pie(x, colors = colors, labels = labels, radius = 1.5,
        wedgeprops={"linewidth": 1, "edgecolor": "white"}, labeldistance = 0.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x7892df59bb50>,
#   <matplotlib.patches.Wedge at 0x7892df59ba60>,
#   <matplotlib.patches.Wedge at 0x7892df599c00>,
#   <matplotlib.patches.Wedge at 0x7892df5d0850>,
#   <matplotlib.patches.Wedge at 0x7892df5d0cd0>],
#  [Text(-0.003103858577075726, 0.749993577347122, 'New York City'),
#   Text(-0.6594389624083911, -0.35726776353002326, 'Los Angeles'),
#   Text(0.06831993925341837, -0.746881775049043, 'Chicago'),
#   Text(0.6216795787322053, -0.41954082207497734, 'Houston'),
#   Text(0.7361469871130292, -0.1434838435657814, 'Phoenix')])

# %%
x = np.arange(10)
cities = df['name'][0:10]
y = df['pop2021'][0:10]
colors = plt.get_cmap('gray_r')(np.linspace(0.2, 0.7, len(x)))
plt.xticks(x, cities)
plt.bar(x, y, edgecolor = 'white', width = 1, color = colors)
# Out:
# <BarContainer object of 10 artists>
